# %% [markdown]
# q1 = check r2 info yourself also check all metrics range and kis ki kitni range hogi tu achamodel ai ga.. i.e task
# # 2 ..metrics ko kasay interpret krna ha
# q2 = take iris data and perform multi linear regression and decision tree classifier
# knn, classification , multi linear regression

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = df[['sepal_length', 'sepal_width', 'petal_length']]
y = df['petal_width']

# %%
df.isnull().sum() / len(x) *100
# Out:
# sepal_length    0.0
# sepal_width     0.0
# petal_length    0.0
# petal_width     0.0
# species         0.0
# dtype: float64

# %%
sns.lmplot(data = df, x='sepal_width', y= 'petal_width')

# %%
sns.boxplot( y = 'sepal_width', data = df_linear)
# Out:
# <Axes: ylabel='sepal_width'>

# %%
df_linear = df[(df['sepal_width'] > 2.3) & (df['sepal_width'] < 4.0)]

# %%
x = df_linear[['sepal_length', 'sepal_width', 'petal_length']]

y =df_linear['sepal_width']

# %%
# now call your model
model = LinearRegression()
# train your model
model.fit(x,y)
# prediction
model.predict([[5.1,3.5,1.4]])
# Out:
# c:\Users\khawar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.5])

# %%
# model evaluation with matrics
# r2
# mean squared error
# Mean Absolute Error
# root nean square error

x_train, x_test , y_train , y_test = train_test_split(x,y, train_size=0.8)

# model 
model = LinearRegression()
model.fit(x_train, y_train)

# prediction 
predictions = model.predict(x_test)
# Out:
# array([3.4, 3.2, 2.6, 3.4, 2.7, 2.9, 3.4, 3.8, 3.6, 3.1, 3.1, 2.8, 2.5,
#        3.6, 3. , 3.2, 2.8, 2.6, 3. , 3.6, 3.1, 3. , 3. , 3.9, 3.4, 3.1,
#        3. , 2.8])

# %%
sns.scatterplot(x =y_test, y =predictions)
# Out:
# <Axes: xlabel='sepal_width'>

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import  mean_squared_error , mean_absolute_error, r2_score

mae = mean_absolute_error(y_true = y_test, y_pred = predictions)
mse = mean_squared_error(y_true = y_test, y_pred = predictions)
rmse = mean_squared_error(y_true = y_test, y_pred = predictions , squared =False)
R2 = r2_score(y_true = y_test, y_pred = predictions)

# print
print ("mae :", mae)
print ("mse :", mse)
print ("rmse :", rmse)
print ("R_squared :", R2)
# Out:
# mae : 5.075305255429287e-16
# mse : 4.085172544894526e-31
# rmse : 6.391535453155623e-16
# R_squared : 1.0
